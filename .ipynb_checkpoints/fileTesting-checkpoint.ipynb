# %%
import sys
sys.path.append("C:\Users\samper\Python\Lib")

import windaq as w
import Tkinter, tkFileDialog

file_to_open = "C:/Users/samper/Desktop/test_01.WDH"

file_contents = w.windaq(file_to_open) # open windaq object

# %%
time = file_contents.time()
inlet= file_contents.data(2)
position = file_contents.data(3)
current = file_contents.data(4)
cmd = file_contents.data(5)

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(time, cmd)
plt.show()
